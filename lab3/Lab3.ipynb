# %% [markdown]
# # Linear models: Support Vector Machines (SVM)

# %% [markdown]
# In this notebook we are going to explore linear models and Support Vector Machines (SVM in short).
#
# Let's first import the required packages.

# %%
#put here your ``numero di matricola''
numero_di_matricola = 7

from sklearn import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## SVM for linearly separable data

# %% [markdown]
# Let's start by creating a simple linearly separable dataset for binary classification, where the instance space is $\mathcal{X} =\mathbb{R}^2$ (so that we can visualize it). Just to make things easier, we are going to rescale it too.

# %%
X, y = datasets.make_blobs(n_samples = 500, centers = 2, n_features = 2, random_state=numero_di_matricola)

scaler = preprocessing.StandardScaler()
scaler.fit(X)
X = scaler.transform(X)

# %% [markdown]
# The following code plots the dataset, it is useful for later parts too.

# %%
plt.title("Plot of dataset")
plt.scatter(X[:, 0], X[:, 1], c=y)

# %% [markdown]
# Now let's run the perceptron, using $\texttt{linear\_model.Perceptron(...)}$ from sklearn. WE fix the number of iterations to 100 so that it runs quickly, and $\texttt{random\_state=10}$.
#
# What do we expect in terms of training error?

# %%
#Create a perceptron classifier
# TO DO: COMPLETE
model_perceptron_1 = linear_model.Perceptron(max_iter=100, random_state=10)


#Training the model
# TO DO: COMPLETE
model_perceptron_1.fit(X,y)


#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_perceptron_1.score(X,y)


#Print the training error
# TO DO: COMPLETE
print("Training error: " + str(training_error))
# Out:
# Training error: 0.0

# %% [markdown]
# The following code plots the *decision boundary* of a model and the training set. It is useful for later parts too.

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_perceptron_1.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])

# %% [markdown]
# If we change the value of $\texttt{random\_state}$ in the perceptron, it will start from a different model.
#
# Let's run the perceptron with $\texttt{random\_state}=$. How will the solution compare to the above?

# %%
#Create a perceptron classifier
# TO DO: COMPLETE
model_perceptron_2 = linear_model.Perceptron(max_iter=100, random_state=12)


#Training the model
# TO DO: COMPLETE
model_perceptron_2.fit(X,y)


#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_perceptron_2.score(X,y)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.0

# %% [markdown]
# What about the decision boundary? Let's plot it.

# %%
plt.scatter(X[:, 0], X[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_perceptron_2.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])

# %% [markdown]
# Which model is better?
#
# Is any of these the *best* choice?

# %% [markdown]
# Now, let's run the hard-SVM on the same data. To obtain (an almost) hard-SVM in sklearn, we can use $\texttt{svm.SVC(...)}$ with a very high value of the parameter $C$.

# %%
#Creating a SVM model
# TO DO: COMPLETE
model_svm = svm.SVC(kernel="linear",C=100000000)


#Training the model
# TO DO: COMPLETE
model_svm.fit(X,y)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm.score(X,y)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.0

# %% [markdown]
# Plot the SVM decision boundary.

# %%
# TO DO: WRITE THE CODE TO PLOT THE DECISION BOUNDARY
plt.scatter(X[:, 0], X[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_svm.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])

# %% [markdown]
# Let's see what the support vectors are. They are defined in attribute $\texttt{support_vectors_}$

# %%
#print the support vectors (attribute support_vectors_)
#TO DO: COMPLETE
print(model_svm.support_vectors_)
# Out:
# [[-0.20498378  0.02693208]
#  [ 0.35281708 -0.99697609]
#  [ 0.41207829  0.10634759]]

# %% [markdown]
# Let's what happens moving one support vector. We first obtain the indices of the support vectors.

# %%
#print the indices of support vectors (attribute support_)
#TO DO: COMPLETE
print(model_svm.support_)

# let's print the coefficients alpha_i's of the support vectors
# (attribute dual_coef)
#alpha= regularization parameter multiplied by their targets
print(model_svm.dual_coef_)
# Out:
# [321 109 417]
# [[-5.34267604  0.54301766  4.79965837]]

# %% [markdown]
# Now let's move one support vector closer to the points in the same class.

# %%
#let's copy the data and maove one support vector close to the points in the same class
#TO DO: COMPLETE
X1 = X.copy()
X1[321,0] = -1

#let's plot the new dataset
#TO DO: COMPLETE
plt.title("Plot of modified dataset")
plt.scatter(X1[:, 0], X1[:, 1], c=y)

# %% [markdown]
# Let's run the SVM on the new data.

# %%
#Creating a SVM model
# TO DO: COMPLETE
model_svm_1 = svm.SVC(kernel="linear",C=100000000)

#Training the model
# TO DO: COMPLETE
model_svm_1.fit(X,y)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_1.score(X1,y)

#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.0

# %% [markdown]
# Plot the SVM decision boundary and the previous decision boundary.

# %%
#TO DO: complete
plt.scatter(X1[:, 0], X1[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z1 = model_svm_1.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])
ax.contour(XX, YY, Z1, colors='b', levels=[0], alpha=1,
linestyles=['-'])

# %% [markdown]
# Now let's move one support vector closer to the points in the otherr class.

# %%
#let's copy the data and maove one support vector close to the points in the same class
#TO DO: COMPLETE
X2 = X.copy()
X2[321,0] = 0.2

#let's plot the new dataset
#TO DO: COMPLETE
plt.title("Plot of modified dataset")
plt.scatter(X2[:, 0], X2[:, 1], c=y)

# %% [markdown]
# Let's run the SVM on the new data.

# %%
#Creating a SVM model
# TO DO: COMPLETE
model_svm_2 = svm.SVC(kernel="linear",C=100000000)

#Training the model
# TO DO: COMPLETE
model_svm_2.fit(X,y)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_2.score(X2,y)

#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.0020000000000000018

# %% [markdown]
# Let's plot the new decision boundary, and the old ones too.

# %%
#TO DO: complete
plt.scatter(X2[:, 0], X2[:, 1], c=y, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z2 = model_svm_2.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])
ax.contour(XX, YY, Z1, colors='b', levels=[0], alpha=1,
linestyles=['-'])
ax.contour(XX, YY, Z2, colors='r', levels=[0], alpha=1,
linestyles=['-'])

# %% [markdown]
# ## SVM for non-linearly separable data

# %% [markdown]
# Let's make a dataset that is not linearly separble, and let's plot it.

# %%
# TO DO: COMPLETE
X_nls, y_nls = datasets.make_blobs(n_samples = 500, centers = 2, n_features = 2, random_state = numero_di_matricola)
scaler.fit(X_nls)
X_nls = scaler.transform(X_nls)

#add some samples which make dataset non-linearly separable
a = np.array([[0.3,2]])
b = np.array([0])
X_nls = np.concatenate((X_nls,a))
y_nls = np.concatenate((y_nls,b))
a = np.array([[0.1,-1.5]])
b = np.array([0])
X_nls = np.concatenate((X_nls,a))
y_nls = np.concatenate((y_nls,b))

a = np.array([[0,0.1]])
b = np.array([1])
X_nls = np.concatenate((X_nls,a))
y_nls = np.concatenate((y_nls,b))

plt.title("Plot of dataset")
plt.scatter(X_nls[:,0], X_nls[:,1], c=y_nls)

# %% [markdown]
# Let's try to learn a hard-SVM. It means that the parameter C, which is approximately equal to $1/\lambda$ with $\lambda$ as in our slides.

# %%
#Creating a hard SVM model
# TO DO: COMPLETE
model_svm_nls = svm.SVC(kernel="linear",C=100000000)

#Training the model
# TO DO: COMPLETE
model_svm_nls.fit(X_nls,y_nls)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_nls.score(X_nls,y_nls)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.001988071570576566

# %% [markdown]
# The following code plots the decision boundary, as well as the margin.

# %%
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of hard SVM decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

#TO DO
Z = model_svm_nls.decision_function(xy).reshape(XX.shape) #COMPLETE

ax.contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)

# %% [markdown]
# Let's try with a smaller value of C ($10^4$), that corresponds to larger value of $\lambda$.
#
# What do you expect?

# %%
#Creating a hard SVM model
# TO DO: COMPLETE
model_svm_nls_1 = svm.SVC(kernel="linear",C=10000)

#Training the model
# TO DO: COMPLETE
model_svm_nls_1.fit(X_nls,y_nls)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_nls_1.score(X_nls,y_nls)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.003976143141153132

# %% [markdown]
# What about the decision boundary and the margin?

# %%
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of hard SVM decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

#TO DO
Z = model_svm_nls_1.decision_function(xy).reshape(XX.shape) #COMPLETE

ax.contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)

# %% [markdown]
# Let's repeat everything for C=100

# %%
#Creating a hard SVM model
# TO DO: COMPLETE
model_svm_nls_2 = svm.SVC(kernel="linear",C=100)

#Training the model
# TO DO: COMPLETE
model_svm_nls_2.fit(X_nls,y_nls)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_nls_2.score(X_nls,y_nls)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.003976143141153132

# %%
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of hard SVM decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

#TO DO
Z = model_svm_nls_2.decision_function(xy).reshape(XX.shape) #COMPLETE

ax.contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)

# %% [markdown]
# And for C=1?

# %%
#Creating a hard SVM model
# TO DO: COMPLETE
model_svm_nls_3 = svm.SVC(kernel="linear",C=1)

#Training the model
# TO DO: COMPLETE
model_svm_nls_3.fit(X_nls,y_nls)

#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_svm_nls_3.score(X_nls,y_nls)


#Print the training error
# TO DO: COMPLETE
print("Training error: ", training_error)
# Out:
# Training error:  0.005964214711729587

# %%
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of hard SVM decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T

#TO DO
Z = model_svm_nls_3.decision_function(xy).reshape(XX.shape) #COMPLETE

ax.contour(
    XX, YY, Z, colors="k", levels=[-1, 0, 1], alpha=0.5, linestyles=["--", "-", "--"]
)

# %% [markdown]
# Let's see what are the support vectors.

# %%
#TO DO COMPLETE:
print(model_svm_nls.support_vectors_)
print(model_svm_nls_1.support_vectors_)
print(model_svm_nls_2.support_vectors_)
print(model_svm_nls_3.support_vectors_)
# Out:
# [[ 0.3         2.        ]
#  [ 0.1        -1.5       ]
#  [ 0.61370643 -2.10055854]
#  [ 0.61353407  1.07014634]
#  [ 0.45854805 -2.04610754]
#  [ 0.          0.1       ]]
# [[ 0.3         2.        ]
#  [ 0.1        -1.5       ]
#  [ 0.61835045  1.89793698]
#  [ 0.41207829  0.10634759]
#  [ 0.          0.1       ]]
# [[ 0.3         2.        ]
#  [ 0.1        -1.5       ]
#  [ 0.61835045  1.89793698]
#  [ 0.41207829  0.10634759]
#  [ 0.          0.1       ]]
# [[-0.38439002 -0.17140959]
#  [-0.45836856 -1.96853588]
#  [-0.20498378  0.02693208]
#  [-0.2637712   2.36361175]
#  [ 0.3         2.        ]
#  [ 0.1        -1.5       ]
#  [ 0.35281708 -0.99697609]
#  [ 0.44659129 -0.34328506]
#  [ 0.45899808 -0.13615956]
#  [ 0.41207829  0.10634759]
#  [ 0.44373116 -0.12888489]
#  [ 0.          0.1       ]]

# %% [markdown]
# Just for comparison, let's run the perceptron on the same dataset with various initial random states

# %%
#Create a perceptron classifier
# TO DO: COMPLETE
model_perceptron_nls = linear_model.Perceptron(max_iter=100, random_state=10)


#Training the model
# TO DO: COMPLETE
model_perceptron_nls.fit(X_nls,y_nls)


#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_perceptron_nls.score(X,y)


#Print the training error
# TO DO: COMPLETE
print("Training error: " + str(training_error))
# Out:
# Training error: 0.0040000000000000036

# %% [markdown]
# Let's plot the decision boundary.

# %%
# TO DO: WRITE THE CODE TO PLOT THE DECISION BOUNDARY
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_perceptron_nls.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])

# %%
#Create a perceptron classifier
# TO DO: COMPLETE
model_perceptron_nls_1 = linear_model.Perceptron(max_iter=100, random_state=numero_di_matricola)


#Training the model
# TO DO: COMPLETE
model_perceptron_nls_1.fit(X_nls,y_nls)


#Get the training error as 1 - score()
# TO DO: COMPLETE
training_error = 1 - model_perceptron_nls_1.score(X,y)


#Print the training error
# TO DO: COMPLETE
print("Training error: " + str(training_error))
# Out:
# Training error: 0.0

# %%
# TO DO: WRITE THE CODE TO PLOT THE DECISION BOUNDARY
plt.scatter(X_nls[:, 0], X_nls[:, 1], c=y_nls, s=30)
ax = plt.gca()
plt.title("Plot of perceptron decision boundary")
xlim = ax.get_xlim()
ylim = ax.get_ylim()
# create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
# use the decision_function call to obtain the boundary to be plot.
# TO DO

Z = model_perceptron_nls_1.decision_function(xy).reshape(XX.shape) #COMPLETE

# plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[0], alpha=1,
linestyles=['-'])
